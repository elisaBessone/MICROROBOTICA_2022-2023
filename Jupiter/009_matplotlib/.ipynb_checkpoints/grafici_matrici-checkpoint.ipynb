# %% [markdown]
# ## GRAFICO DI UNA MATRICE

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dati = np.random.normal(0., 1., size = (100,100))
dati
# Out:
# array([[-1.91230131,  0.13348275,  0.16561793, ..., -0.08527088,
#          0.90112765,  0.70223417],
#        [ 0.61202917, -0.60978086,  0.6652516 , ...,  1.05047234,
#         -1.1936654 , -1.00845736],
#        [-0.28542368, -0.06624407,  1.49315436, ..., -0.47389474,
#         -0.69116539, -1.03810686],
#        ...,
#        [ 0.38024145, -1.62737352, -0.74774987, ...,  0.28543889,
#         -0.36972505,  0.12936622],
#        [ 0.31044987, -1.09019338,  0.08477983, ...,  0.34253446,
#         -2.22961363,  1.44903993],
#        [ 0.58840747, -0.65331388,  0.32887888, ...,  0.23971388,
#         -0.45396311,  1.01180139]])

# %%
dati.shape
# Out:
# (100, 100)

# %%
fig, ax = plt.subplots(figsize = (10, 10))

ax.imshow(dati, cmap = "RdPu")


plt.show()

# %%
immagine = plt.imread("./IMG_8150.JPG")

# %%
fig, ax = plt.subplots()

ax.imshow(immagine[:,:,1], cmap= "Greys")    #immagine[:,:,2] considera la componente 2

plt.show()

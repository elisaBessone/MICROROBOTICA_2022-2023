# %% [markdown]
# ### ISTOGRAMMI

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Istogramma lancio due dadi

# %%
n_lanci = 10000
dado1 = np.random.randint(1,7, n_lanci)
dado2 = np.random.randint(1,7, n_lanci)

somma_dadi = dado1 + dado2

# %%
fig, ax = plt.subplots(figsize = (16,8))
ax.hist(somma_dadi, bins = 11)     #bins --> numero di barre che voglio
plt.show()

# %% [markdown]
# #### Istogramma voti scolastici

# %%
voti = np.random.randint(2,11,100)
voti
# Out:
# array([10,  8,  9,  3,  4,  3,  2,  2,  7,  3,  8,  7,  3, 10,  8,  3,  3,
#         5,  9,  2,  2,  6,  8,  2,  4,  7,  8,  9,  9,  9,  6,  9,  4,  7,
#         5,  3,  9,  9, 10,  8,  4,  4,  7,  9,  3,  2,  6,  6,  9, 10,  4,
#         4,  3, 10,  6,  3, 10,  9,  5,  9, 10,  3, 10,  7, 10, 10,  3, 10,
#         4,  7,  5,  6,  2,  2,  9, 10,  5,  9,  7,  8,  2,  5,  6,  8,  6,
#         3,  8,  7,  7,  5,  6,  5,  8,  9,  9,  3,  8,  7,  7, 10])

# %%
fix, ax = plt.subplots(figsize = (16,8))
ax.hist(voti, bins = 9)
plt.show()

# %%
#### Istogramma

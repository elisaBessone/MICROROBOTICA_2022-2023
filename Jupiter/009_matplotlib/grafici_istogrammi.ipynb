# %% [markdown]
# ### ISTOGRAMMI

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Istogramma lancio due dadi

# %%
n_lanci = 10000
dado1 = np.random.randint(1,7, n_lanci)
dado2 = np.random.randint(1,7, n_lanci)

somma_dadi = dado1 + dado2

# %%
fig, ax = plt.subplots(figsize = (16,8))
ax.hist(somma_dadi, bins = 11)     #bins --> numero di barre che voglio
plt.show()

# %% [markdown]
# #### Istogramma voti scolastici

# %%
voti = np.random.randint(2,11,100)
voti
# Out:
# array([ 8,  4,  4,  3,  6,  5,  5,  9,  6,  5,  5,  9,  3,  4,  6,  9,  9,
#         2,  2,  3,  5,  5,  7,  8,  4,  5,  2,  2,  8,  4,  3,  6,  9,  8,
#         8,  6,  5,  3,  9,  4,  2,  6,  7,  4,  6, 10, 10,  3, 10,  5,  4,
#         8,  6,  2,  6, 10,  3, 10,  9,  7,  8,  2,  7,  3,  6,  7,  3,  5,
#         6, 10,  3,  7,  2,  5,  5, 10,  4,  2,  7,  9,  2,  7,  3,  2,  4,
#         8, 10,  6,  3, 10,  2,  5,  5, 10,  8,  3,  8,  7,  3,  4])

# %%
fix, ax = plt.subplots(figsize = (16,8))
ax.hist(voti, bins = 9)
ax.set_xlabel("voti")
ax.set_ylabel("frequenza assoluta")

plt.show()

# %%
#### Istogramma
